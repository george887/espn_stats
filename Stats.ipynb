# %%
import pandas as pd
import numpy as np

from requests import get
import re
from bs4 import BeautifulSoup
import os
import requests

# %%
url = 'https://www.espn.com/nba/stats/team/_/view/team/table/offensive/sort/avgPoints/dir/desc'
headers = {'User-Agent': 'user-agent'} # Some websites don't accept the pyhon-requests default user-agent
response = get(url, headers=headers)

# %%
print(response.text[:400])
# Out:
#         <!doctype html>
#         <html lang="en">
#             <head>
#                 <meta charSet="utf-8" />
#
#                 <!-- ESPNFITT | c515c8292283 | 4424 | 4b3434d5f3089b9f59edd134fdc28c74382584d2 | Mon, 08 Feb 2021 19:14:44 GMT -->
#                 <script type='text/javascript' >
#         ;(function(){
#             function gc(n){var r=document.cookie.match("(^|;) ?"+n+"=([^;]*)(;|$)");ret

# %%
#Make a soup variable holding the response content
soup = BeautifulSoup(response.content, 'html.parser')

# %%
# Page title
soup.title.string
# Out:
# '2020-21 NBA Team   Stats | ESPN'

# %%
# Prints out the HTML
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <!-- ESPNFITT | c515c8292283 | 4424 | 4b3434d5f3089b9f59edd134fdc28c74382584d2 | Mon, 08 Feb 2021 19:14:44 GMT -->\n  <script type="text/javascript">\n   ;(function(){\n            function gc(n){var r=document.cookie.match("(^|;) ?"+n+"=([^;]*)(;|$)");return r?r[2]:null}function sc(n){document.cookie=n}function smpl(n){var r=n/100;return!!r&&Math.random()<=r}var _nr=!1,_nrCookie=gc("_nr");null!==_nrCookie?"1"===_nrCookie&&(_nr=!0):smpl(100)?(_nr=!0,sc("_nr=1; path=/")):(_nr=!1,sc("_nr=0; path=/"));;\n            _nr && window.NREUM||(NREUM={});NREUM.init={distributed_tracing:{enabled:true}};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){fu
# ...

# %%
# Finding all the anchor tags
soup.find_all("a")
# Out:
# [<a class="ScoreCell__Link" data-game-link="true"><div class="ScoreCell__Link__Event__Detail"><div class="ScoreCell__CompetitorDetails"><ul class="ScoreCell__Competitors"></ul></div></div></a>,
#  <a class="Nav__Primary__ToggleMenu" href="#"><span>Menu</span></a>,
#  <a class="AnchorLink Nav__Primary__Branding Nav__Primary__Branding--espn" href="/" tabindex="0">ESPN</a>,
#  <a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/nfl/" tabindex="0"><span class="Nav__Text">NFL</span></a>,
#  <a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/nba/" tabindex="0"><span class="Nav__Text">NBA</span></a>,
#  <a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/soccer/" tabindex="0"><span class="Nav__Text">Soccer</span></a>,
# ...

# %%
# Finding the h1 element
soup.find("h1")
# Out:
# <h1 class="headline headline__h1 dib">NBA Team   Stats 2020-21</h1>

# %%
soup.get_text()
# Out:
# "\n\n\n\n\n\n\n2020-21 NBA Team   Stats | ESPN\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to navigationMenuESPNNFLNBASoccerNCAAMMMATennisWatchListenFantasyNBAHomeScoresScheduleStandingsStatsTeamsFantasy BasketballNBA Trade MachineDaily LinesDraftMoreNBA Team   Stats 2020-21TeamOpponentDifferential2020-21 Regular Season2019-20 Postseason2019-20 Regular Season2018-19 Postseason2018-19 Regular Season2017-18 Postseason2017-18 Regular Season2016-17 Postseason2016-17 Regular Season2015-16 Postseason2015-16 Regular Season2014-15 Postseason2014-15 Regular Season2013-14 Postseason2013-14 Regular Season2012-13 Postseason2012-13 Regular Season2011-12 Postseason2011-12 Regular Season2010-11 Postseason2010-11 Regular Season2009-10 Postseason2009-10 Regular Season2008-09 Postseason2008-09 Regular Season2007-08 Postseason2007-08 Regular Season2006-07 Postseason2006-07 Regular Season2005-06 Postseason2005-06 Regular Season2004-05 Postseason2004-05 Regular Season2003-04 Postseason2
# ...

# %%
soup.select('Brooklyn Nets')
# Out:
# []

# %%
article = soup.find('td', class_ ="Table__TD")
article.text
# Out:
# '1'

# %%
article = soup.find('tr', class_ ="Table__TR")
article.text
# Out:
# 'RKTeam'

# %%
article = soup.find('tbody', class_ ="Table__TBODY")
article.text
# Out:
# '1Brooklyn Nets2Milwaukee Bucks3Denver Nuggets4Chicago Bulls5Portland Trail Blazers6LA Clippers7Golden State Warriors8Utah Jazz8Washington Wizards10Philadelphia 76ers11Sacramento Kings12Indiana Pacers13Los Angeles Lakers14Toronto Raptors15Atlanta Hawks16New Orleans Pelicans17San Antonio Spurs18Houston Rockets19Boston Celtics20Dallas Mavericks21Charlotte Hornets22Memphis Grizzlies23Phoenix Suns24Detroit Pistons25Oklahoma City Thunder26Miami Heat27Minnesota Timberwolves28Orlando Magic29Cleveland Cavaliers30New York Knicks'

# %%
def make_soup(url):
    '''
    This helper function takes in a url and requests and parses HTML
    returning a soup object.
    '''
    # set headers and response variables
    headers = {'User-Agent': 'user-agent'} 
    response = get(url, headers=headers)
    # use BeartifulSoup to make object
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# %%
make_soup(url)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <!-- ESPNFITT | 1e39a5c1ddfd | 4424 | 4b3434d5f3089b9f59edd134fdc28c74382584d2 | Mon, 08 Feb 2021 19:19:37 GMT -->
# <script type="text/javascript">
#         ;(function(){
#             function gc(n){var r=document.cookie.match("(^|;) ?"+n+"=([^;]*)(;|$)");return r?r[2]:null}function sc(n){document.cookie=n}function smpl(n){var r=n/100;return!!r&&Math.random()<=r}var _nr=!1,_nrCookie=gc("_nr");null!==_nrCookie?"1"===_nrCookie&&(_nr=!0):smpl(100)?(_nr=!0,sc("_nr=1; path=/")):(_nr=!1,sc("_nr=0; path=/"));;
# ...

# %%
article = soup.find('tr', class_ ="Table__TR Table__TR--sm Table__even")
article.text
# Out:
# '1Brooklyn Nets'
